# %%
print("naruto and sasuke are best %s." %'rivals')
# Out:
# naruto and sasuke are best rivals.

# %%
print("team 7 is of naruto %s." %'Sakura, sasuke')
# Out:
# team 7 is of naruto Sakura, sasuke.

# %%
print("one of the greatest shinobis are %s, and %s."  %('jiraiya','orochimaru'))
# Out:
# one of the greatest shinobis are jiraiya, and orochimaru.

# %%
print('He said his name was %s.' %'eren')
print('She said her name was %r.' %'mikasa')
# Out:
# He said his name was eren.
# She said her name was 'mikasa'.

# %%
print('the world shall %s.' %'know \tpain')
print('the world shall %r.' %'know pain')
# Out:
# the world shall know 	pain.
# the world shall 'know pain'.

# %%
print('I wrote %s programs today.' %6.69)
print('I wrote %d programs today.' %6.69)
# Out:
# I wrote 6.69 programs today.
# I wrote 6 programs today.

# %%
print('Floating point numbers: %9.2f' %(13.144))
# Out:
# Floating point numbers:     13.14

# %%
print('Floating point numbers: %10.3f' %(13.144))
# Out:
# Floating point numbers:     13.144

# %%
print('Floating point numbers: %13.7f' %(13.144))
# Out:
# Floating point numbers:    13.1440000

# %%
print('team {2} {1} {0}'. format('naruto','sakura','sasuke'))
# Out:
# team sasuke sakura naruto

# %%
print('First Object: {a}, Second Object: {b}, Third Object: {c}'.format(a='69',b='eren',c='pi'))
# Out:
# First Object: 69, Second Object: eren, Third Object: pi

# %%
print('A %s saved is a %s earned.' %('rupee','rupee'))
# vs.
print('A {p} saved is a {p} earned.'.format(p='rupee'))
# Out:
# A rupee saved is a rupee earned.
# A rupee saved is a rupee earned.

# %%
print('{0:10} | {1:8}'.format('Fruit', 'Quantity'))
print('{0:10} | {1:8}'.format('Apples', 6.))
print('{0:10} | {1:8}'.format('Oranges', 9))
# Out:
# Fruit      | Quantity
# Apples     |      6.0
# Oranges    |        9

# %%
print('{0:<6} | {1:^9} | {1:>8}'.format('Left','Center','Right'))
print('{0:<6} | {1:^9} | {1:>8}'.format(11,22,33))
# Out:
# Left   |  Center   |   Center
# 11     |    22     |       22

# %%
print('This is my ten-character, three-decimal number:%10.3f' %13.5889)
print('This is my ten-character, three-decimal number:{0:10.3f}'.format(13.5889))
# Out:
# This is my ten-character, three-decimal number:    13.589
# This is my ten-character, three-decimal number:    13.589

# %%
name = 'jake'

print(f"His friend name is {name}.")
# Out:
# His friend name is jake.

# %%
print(f"He said his name is {name!r}.")
# Out:
# He said his name is 'jake'.
